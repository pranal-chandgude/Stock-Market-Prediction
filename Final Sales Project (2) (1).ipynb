# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline 
from datetime import datetime

# %%
stock= pd.read_csv("C:\\Users\\DELL\\Downloads\\AAPL.csv")

# %%
stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 2006  2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007  2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008  2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009  2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010  2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 0     75555200
# ...

# %%
stock.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709  75555200
# 1  2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536  65005500
# 2  2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175  67817400
# 3  2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630  79573200
# 4  2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932  98506100

# %%
stock.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
stock.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean    126.707469   127.827594   125.580258   126.741235   119.505548
# std      50.483753    50.926301    50.124940    50.578369    52.438444
# min      55.424286    57.085712    55.014286    55.790001    48.921928
# 25%      85.882858    86.717858    85.056427    86.202145    75.056679
# 50%     113.050003   114.190002   111.870003   113.050003   105.222908
# 75%     165.190002   167.409996   163.424995   165.245002   160.047111
# max     291.119995   293.970001   288.119995   291.519989   289.522614
#
#              Volume
# count  2.011000e+03
# mean   5.949670e+07
# std    4.683856e+07
# min    1.136200e+07
# 25%    2.758565e+07
# 50%    4.346900e+07
# 75%    7.471030e+07
# max    3.765300e+08

# %%
stock['Close'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:>

# %%
data=stock['Date']

# %%
data
# Out:
# 0       2012-01-03
# 1       2012-01-04
# 2       2012-01-05
# 3       2012-01-06
# 4       2012-01-09
#            ...
# 2006    2019-12-23
# 2007    2019-12-24
# 2008    2019-12-26
# 2009    2019-12-27
# 2010    2019-12-30
# Name: Date, Length: 2011, dtype: object

# %%
# Converting the data type of Date feature into datetime from object
stock['Date'] = pd.to_datetime(stock['Date'], infer_datetime_format=True)
indexedData = stock.set_index(['Date'])

# %%
indexedData
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...                ...         ...         ...         ...         ...
# 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#               Volume
# Date
# 2012-01-03  75555200
# 2012-01-04  65005500
# 2012-01-05  67817400
# ...

# %%
indexedData.index
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2019-12-16', '2019-12-17', '2019-12-18', '2019-12-19',
#                '2019-12-20', '2019-12-23', '2019-12-24', '2019-12-26',
#                '2019-12-27', '2019-12-30'],
#               dtype='datetime64[ns]', name='Date', length=2011, freq=None)

# %%
# plotting the stock high on year time frame,by this graph we can see the volume of the data.
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(indexedData)

# %%
#from this graph we can see the "High" values of the data from 2012 to 2020.
indexedData['Close'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#with this we can see min values of the perticular year.
indexedData.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-12-31   58.485714   58.928570   58.428570   58.747143   50.765709
# 2013-12-31   55.424286   57.085712   55.014286   55.790001   48.921928
# 2014-12-31   70.739998   71.647141   70.507141   71.397141   63.808632
# 2015-12-31   94.870003  107.029999   92.000000  103.120003   95.294647
# 2016-12-31   90.000000   91.669998   89.470001   90.339996   84.809998
# 2017-12-31  115.800003  116.330002  114.760002  116.019997  110.070328
# 2018-12-31  148.149994  151.550003  146.589996  146.830002  143.665421
# 2019-12-31  143.979996  145.720001  142.000000  142.190002  139.125412
#
#               Volume
# Date
# 2012-12-31  43938300
# 2013-12-31  41888700
# 2014-12-31  14479600
# 2015-12-31  13046400
# 2016-12-31  11475900
# 2017-12-31  14026700
# 2018-12-31  12513900
# 2019-12-31  11362000

# %%
#with this we can see max values of the perticular year. Rule A means year end frequency.
indexedData.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-12-31  100.344284  100.724289   99.938568  100.300003   87.045334
# 2013-12-31   81.807144   82.162857   80.915718   81.441429   72.785355
# 2014-12-31  119.269997  119.750000  118.050003  119.000000  108.590118
# 2015-12-31  134.460007  134.539993  131.399994  133.000000  121.930191
# 2016-12-31  118.180000  118.690002  117.449997  118.250000  111.612923
# 2017-12-31  175.110001  177.199997  174.860001  176.419998  170.064453
# 2018-12-31  230.779999  233.470001  229.779999  232.070007  226.278717
# 2019-12-31  291.119995  293.970001  288.119995  291.519989  289.522614
#
#                Volume
# Date
# 2012-12-31  376530000
# 2013-12-31  365213100
# 2014-12-31  266380800
# 2015-12-31  162206300
# 2016-12-31  133369700
# 2017-12-31  111985000
# 2018-12-31   96246700
# 2019-12-31   91312200

# %%
#rise in stock price 
indexedData.resample(rule='A').max()['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
year=indexedData.resample(rule='A').mean()["Close"].plot(figsize=(15,6))

# %%
# Rule QS shows quarterly data.
indexedData.resample(rule='QS').mean()["Close"].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#calculate Rolling Mean , aslo we can fgind max,min as well.
indexedData['Close'].rolling(10).mean().head(20)
# Out:
# Date
# 2012-01-03          NaN
# 2012-01-04          NaN
# 2012-01-05          NaN
# 2012-01-06          NaN
# 2012-01-09          NaN
# 2012-01-10          NaN
# 2012-01-11          NaN
# 2012-01-12          NaN
# 2012-01-13          NaN
# 2012-01-17    59.978857
# 2012-01-18    60.234286
# 2012-01-19    60.438714
# 2012-01-20    60.471143
# 2012-01-23    60.542714
# 2012-01-24    60.523857
# 2012-01-25    60.858429
# 2012-01-26    61.173857
# 2012-01-27    61.543715
# 2012-01-30    62.018000
# 2012-01-31    62.472000
# Name: Close, dtype: float64

# %%
# adding column of rolling mean of open in the data frame.
indexedData['Close:30 days rolling']=indexedData['Close'].rolling(10).mean()

# %%
indexedData.head(30)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2012-01-03  58.485714  58.928570  58.428570  58.747143  50.765709   75555200
# 2012-01-04  58.571430  59.240002  58.468571  59.062859  51.038536   65005500
# 2012-01-05  59.278572  59.792858  58.952858  59.718571  51.605175   67817400
# 2012-01-06  59.967144  60.392857  59.888573  60.342857  52.144630   79573200
# 2012-01-09  60.785713  61.107143  60.192856  60.247143  52.061932   98506100
# 2012-01-10  60.844284  60.857143  60.214287  60.462856  52.248333   64549100
# 2012-01-11  60.382858  60.407143  59.901428  60.364285  52.163139   53771200
# 2012-01-12  60.325714  60.414288  59.821430  60.198570  52.019955   53146800
# 2012-01-13  59.957142  60.064285  59.808571  59.972858  51.824898   56505400
# 2012-01-17  60.599998  60.855713  60.422855  60.671429  52.428562   60724300
# 2012-01-18  60.994286  61.352856  60.900002  61.301430  52.972977   69197800
# ...

# %%
#plotting two columns of same data ('Open' and 'open:30 days rolling').
indexedData[['Close','Close:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Orange line indicates smoothened version

# %% [markdown]
# # Outlier Detection

# %%
import seaborn as sns
sns.boxplot(indexedData['Close'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
indexedData= indexedData.reset_index()

# %%
indexedData
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1    2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2    2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3    2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4    2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume  Close:30 days rolling
# ...

# %%
indexedData["Date"] = pd.to_datetime(stock.Date,format="%Y-%m-%d")

indexedData["Month"] = indexedData['Date'].dt.strftime("%m") # month extraction
indexedData["year"] = indexedData['Date'].dt.strftime("%Y")

# %%
import seaborn as sns
plt.figure(figsize=(8,6))

plt.subplot(211)

sns.boxplot(x="Month",y="Close", data= indexedData)

plt.subplot(212)

sns.boxplot (x="year",y="Close", data=indexedData)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Close'>

# %%
#percentile25 = indexedData['Close'].quantile(0.25)
#percentile75 = indexedData['Close'].quantile(0.75)
#iqr = percentile75 - percentile25

# %%
#upper_limit = percentile75 + 1.5 * iqr
#lower_limit = percentile25 - 1.5 * iqr

# %%
#indexedData[indexedData['Close'] > upper_limit]
#indexedData[indexedData['Close'] < lower_limit]

# %%
#indexedData.shape

# %%
#indexedData1 = indexedData[indexedData['Close'] > upper_limit]
#indexedData1

# %%
#indexedData2 = indexedData[indexedData['Close'] < lower_limit]
#indexedData2

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(indexedData['Close'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Close', ylabel='Density'>

# %%
#Time series decomposition plot
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
rcParams['figure.figsize'] = 12,8
decompose_ts_add = seasonal_decompose(indexedData['Close'],model='additive',period=360)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# Test of Stationarity:
# Time Series is Stationary if we have constant mean, constant variance and No Trend and No Seasonality
#
# But in our data set we can see uprising trend and also seasonality is present, So we can say that our data is Non-Stationary.
#
# ADF(Augmented Dickey-Fuller) Test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adfuller_test(close):
    result = adfuller(close)
    labels = ['ADF Test Statistic', 'p-value','#Lags Used', 'Number of Observations used']
    for value, label in zip(result, labels):
        print(label+' : ' +str(value))
    if result[1] <= 0.05:
        print("Reject Null Hypothesis. Data is Stationary")
    else:
        print("Accept Null Hypothesis. Data is Non - Stationary")

# %%
adfuller_test(indexedData['Close'])
# Out:
# ADF Test Statistic : 1.2193701254378042
# p-value : 0.996117017803201
# #Lags Used : 9
# Number of Observations used : 2001
# Accept Null Hypothesis. Data is Non - Stationary

# %% [markdown]
# Differencing

# %%
#Change for (t)th day is Close for (t)th day minus Close for (t-1)th day.
indexedData['Diff'] = indexedData['Close'].diff()

# Plot the Change
plt.figure(figsize=(10, 7))
plt.plot(indexedData['Diff'])
plt.title('First Order Differenced Series', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Difference', fontsize=12)
plt.show()

# %%
adfuller_test(indexedData['Diff'].dropna())
# Out:
# ADF Test Statistic : -13.625534323873268
# p-value : 1.7631231987208899e-25
# #Lags Used : 8
# Number of Observations used : 2001
# Reject Null Hypothesis. Data is Stationary

# %% [markdown]
# ACF plots and PACF plots

# %%
# Original Data
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf((indexedData['Close'].dropna()),lags=30)
tsa_plots.plot_pacf((indexedData['Close'].dropna()),lags=30)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# After Differencing
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf((indexedData['Diff'].dropna()),lags=30)
tsa_plots.plot_pacf((indexedData['Diff'].dropna()),lags=30)
plt.show()

# %% [markdown]
# ARIMA Model

# %%
stock.drop(["Open",'High','Low','Adj Close','Volume'], axis = 1, inplace = True)
stock.set_index('Date', inplace=True)
stock.head()
# Out:
#                 Close
# Date
# 2012-01-03  58.747143
# 2012-01-04  59.062859
# 2012-01-05  59.718571
# 2012-01-06  60.342857
# 2012-01-09  60.247143

# %%
split_date = "2018-01-01"
train = stock.loc[stock.index < split_date]
test = stock.loc[stock.index >= split_date]
print("Train data :", train.shape)
print("Test data :",test.shape)
# Out:
# Train data : (1509, 1)
# Test data : (502, 1)

# %%
plt.plot(train, label = 'Train')
plt.plot(test, label='Test')
plt.title("Data Splitting", size = 25, y = 1.02)
plt.xlabel("Year", size=15);plt.ylabel('Close Price', size = 15)
plt.legend()
plt.show()

# %% [markdown]
# ARIMA model

# %%
from statsmodels.tsa.arima.model import ARIMA
#model_arima = ARIMA(train['Close'],order = (1,1,1))
model_arima = ARIMA(train['Close'],order = (2,1,2))
result = model_arima.fit()
result.summary()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
test_pred = pd.DataFrame(result.predict(len(train),len(train)+501,type='levels'))
test_pred.index = test.index
test_pred
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#             predicted_mean
# Date
# 2018-01-02      169.412568
# 2018-01-03      169.400695
# 2018-01-04      169.216331
# 2018-01-05      169.128542
# 2018-01-08      169.260942
# ...                    ...
# 2019-12-23      169.280285
# 2019-12-24      169.280078
# 2019-12-26      169.280270
# 2019-12-27      169.280576
# 2019-12-30      169.280554
#
# [502 rows x 1 columns]

# %%
plt.figure(figsize=(12,5), dpi=80)
plt.plot(train['Close'], label = 'Train')
plt.plot(test['Close'], label='Test')
plt.plot(test_pred, label='Prediction')
plt.title('Actuals vs Prediction');plt.xlabel("Year", size=15);plt.ylabel('Close Price', size = 15)
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error,mean_absolute_error
from math import sqrt

# %%
mse = mean_squared_error(test_pred['predicted_mean'],test['Close'])
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(test_pred.predicted_mean,test.Close)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(test_pred.predicted_mean,test.Close)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  1734.92529507807
# Root Mean Squared Error (RMSE) =  41.65
# Mean Absolute Error (MAE)  =  31.518282066734614
# Mean Absolute Percentage Error (MAPE)  =  0.18619009050704108

# %% [markdown]
# ### SARIMA

# %%
#plot
fig, axes = plt.subplots(2,1,figsize=(12,5),dpi=100,sharex=True)

#usual diffrencing
axes[0].plot(stock["Close"], label='Original Series')
axes[0].plot(stock["Close"].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)

# Seasinal Dei
axes[1].plot(stock["Close"], label='Original Series')
axes[1].plot(stock["Close"].diff(60), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('Apple Stock Sales', fontsize=16)
plt.show()

# %%
import itertools
p = range(0, 3)
d = range(1,2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 60) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 60)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 60)
# SARIMAX: (0, 1, 2) x (1, 1, 0, 60)
# SARIMAX: (0, 1, 2) x (1, 1, 1, 60)

# %%
import statsmodels.api as sm
model_SA = sm.tsa.SARIMAX(train['Close'], order=(0,1,2), seasonal_order=(1,1,0,57))
result_SA = model_SA.fit()
result_SA.summary()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                               Close   No. Observations:                 1509
# Model:             SARIMAX(0, 1, 2)x(1, 1, [], 57)   Log Likelihood               -2954.624
# Date:                             Mon, 06 Feb 2023   AIC                           5917.249
# Time:                                     17:20:10   BIC                           5938.369
# ...

# %%
test_pred_SA = pd.DataFrame(result_SA.predict(len(train),len(train)+501,type='levels'))
test_pred_SA.index = test.index
test_pred_SA
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#             predicted_mean
# Date
# 2018-01-02      168.805051
# 2018-01-03      169.231194
# 2018-01-04      169.907122
# 2018-01-05      170.721257
# 2018-01-08      172.488778
# ...                    ...
# 2019-12-23      263.758283
# 2019-12-24      263.811692
# 2019-12-26      265.074414
# 2019-12-27      263.519888
# 2019-12-30      263.382312
#
# [502 rows x 1 columns]

# %%
plt.figure(figsize=(12,5), dpi=80)
plt.plot(train['Close'], label = 'Train')
plt.plot(test['Close'], label='Test')
plt.plot(test_pred_SA, label='Prediction')
plt.title('Actuals vs Prediction');plt.xlabel("Year", size=15);plt.ylabel('Close Price', size = 15)
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
mse = mean_squared_error(test_pred_SA['predicted_mean'],test['Close'])
print(f'Mean Squared Error (MSE) = ',mse)
rmse = np.round(np.sqrt(mse),2)
print(f'Root Mean Squared Error (RMSE) = ',rmse)
mae = mean_absolute_error(test_pred_SA.predicted_mean,test.Close)
print(f'Mean Absolute Error (MAE)  = ', mae)
mape = mean_absolute_percentage_error(test_pred_SA.predicted_mean,test.Close)
print(f'Mean Absolute Percentage Error (MAPE)  = ', mape)
# Out:
# Mean Squared Error (MSE) =  1068.9944404244684
# Root Mean Squared Error (RMSE) =  32.7
# Mean Absolute Error (MAE)  =  25.686027929682673
# Mean Absolute Percentage Error (MAPE)  =  0.11347752664812408

# %% [markdown]
# Forecasting for next 30 days

# %%
forecast_SA = result_SA.predict(len(stock), len(stock)+31, type = 'levels')
forecast_SA
index_future_dates = pd.date_range(start='2019-12-30', end = '2020-01-30')
forecast_SA.index=index_future_dates
print(forecast_SA)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 2019-12-30    262.891356
# 2019-12-31    264.928488
# 2020-01-01    266.913602
# 2020-01-02    265.351498
# 2020-01-03    265.513586
# 2020-01-04    265.842008
# 2020-01-05    266.071031
# 2020-01-06    262.806921
# 2020-01-07    263.479555
# 2020-01-08    263.764713
# 2020-01-09    262.731671
# 2020-01-10    262.472492
# 2020-01-11    262.975158
# 2020-01-12    263.232031
# 2020-01-13    264.106283
# 2020-01-14    266.257497
# 2020-01-15    265.659304
# 2020-01-16    264.830142
# 2020-01-17    262.074910
# 2020-01-18    262.702392
# 2020-01-19    265.063450
# 2020-01-20    265.142321
# 2020-01-21    264.966404
# 2020-01-22    266.449849
# 2020-01-23    270.602063
# 2020-01-24    273.356237
# 2020-01-25    272.932169
# 2020-01-26    272.249530
# ...

# %%
plt.figure(figsize=(12,5), dpi=80)
plt.plot(train['Close'], label = 'Train')
plt.plot(test['Close'], label='Test')
plt.plot(forecast_SA, label='Prediction')
plt.title('Actuals vs Prediction');plt.xlabel("Year", size=15);plt.ylabel('Close Price', size = 15)
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %% [markdown]
# # Stacked LSTM model - Long Short Term Momery model

# %%
stock
# Out:
#                  Close
# Date
# 2012-01-03   58.747143
# 2012-01-04   59.062859
# 2012-01-05   59.718571
# 2012-01-06   60.342857
# 2012-01-09   60.247143
# ...                ...
# 2019-12-23  284.000000
# 2019-12-24  284.269989
# 2019-12-26  289.910004
# 2019-12-27  289.799988
# 2019-12-30  291.519989
#
# [2011 rows x 1 columns]

# %% [markdown]
# # Dividing into test and train

# %%
train = stock.iloc[:-202]
test = stock.iloc[-202:]

# %%
## We want to create a numpy arrary not a vector 
trainig_set= train.values
test_set= test.values

# %% [markdown]
# # Scaling the data to MinMaxScaler

# %%
# Feature scalling, Here we will do normalizatioin 
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1))
trainig_set_scaled= sc.fit_transform(trainig_set)

# %% [markdown]
# # Creating the data structure with time steps

# %%
# Create a data structure with 60 timesteps and 1 output
X_train=[] #Independent variables
y_train= [] # Dependent variables 
# I am going to append past 60 days data 
for i in range(202,1809):
    X_train.append(trainig_set_scaled[i-60:i,0]) # Appending prevois 60 days data not including 60
    y_train.append(trainig_set_scaled[i,0])
    
X_train, y_train= np.array(X_train), np.array(y_train)

# %%
# lETS CHECK THE SHAPE OF X_train and y_train
X_train.shape, y_train.shape
# Out:
# ((1607, 60), (1607,))

# %% [markdown]
# # Reshaping the from 2D to 3D

# %%
# LSMT Model needs to be 3- dimensional, so need to rehsape the x_train, y_train
# Reshaping
#numpy.reshape(array, shape, order = 'C')
X_train= np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_train.shape
# Out:
# (1607, 60, 1)

# %% [markdown]
# # LSTM model building

# %%
# Importing the Keras libraries and packages
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

#  Initialising the RNN
model= Sequential()

# Adding first LSTM layer and some dropout Dropout regularisation
model.add(LSTM(units=100,return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(Dropout(rate=0.2))

# Adding second LSTM layer and some dropout Dropout regularisation
model.add(LSTM(units=100,return_sequences=True))
model.add(Dropout(rate=0.2))

# Adding third LSTM layer and some dropout Dropout regularisation
model.add(LSTM(units=100,return_sequences=True))
model.add(Dropout(rate=0.2))

# Adding fourth LSTM layer and some dropout Dropout regularisation
model.add(LSTM(units=100,return_sequences=True))
model.add(Dropout(rate=0.2))

# Adding fifth LSTM layer and some dropout Dropout regularisation
model.add(LSTM(units=100))
model.add(Dropout(rate=0.2))

# Adding the Output Layer
model.add(Dense(units=1))

# Compiling the Model
# Because we're doing regression hence mean_squared_error
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 60, 100)           40800
#
#  dropout (Dropout)           (None, 60, 100)           0
#
#  lstm_1 (LSTM)               (None, 60, 100)           80400
#
#  dropout_1 (Dropout)         (None, 60, 100)           0
#
#  lstm_2 (LSTM)               (None, 60, 100)           80400
#
#  dropout_2 (Dropout)         (None, 60, 100)           0
#
#  lstm_3 (LSTM)               (None, 60, 100)           80400
#
#  dropout_3 (Dropout)         (None, 60, 100)           0
#
#  lstm_4 (LSTM)               (None, 100)               80400
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# ...
# Total params: 362,501
# Trainable params: 362,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the model to the Training set
history=model.fit(X_train,y_train,epochs=20,batch_size=64)
# Out:
# Epoch 1/20
# 26/26 [==============================] - 28s 580ms/step - loss: 0.0299
# Epoch 2/20
# 26/26 [==============================] - 13s 501ms/step - loss: 0.0038
# Epoch 3/20
# 26/26 [==============================] - 13s 496ms/step - loss: 0.0033
# Epoch 4/20
# 26/26 [==============================] - 13s 515ms/step - loss: 0.0035
# Epoch 5/20
# 26/26 [==============================] - 14s 545ms/step - loss: 0.0029
# Epoch 6/20
# 26/26 [==============================] - 13s 497ms/step - loss: 0.0028
# Epoch 7/20
# 26/26 [==============================] - 14s 527ms/step - loss: 0.0029
# Epoch 8/20
# 26/26 [==============================] - 12s 477ms/step - loss: 0.0026
# Epoch 9/20
# 26/26 [==============================] - 13s 481ms/step - loss: 0.0021
# Epoch 10/20
# 26/26 [==============================] - 13s 484ms/step - loss: 0.0026
# Epoch 11/20
# 26/26 [==============================] - 13s 513ms/step - loss: 0.0024
# Epoch 12/20
# ...

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test.shape
# Out:
# (202, 1)

# %% [markdown]
# # Giving the 60 days input and predicting the next 202 days stock price

# %%
test_predictions = []

first_eval_batch = trainig_set_scaled[-60:]
current_batch = first_eval_batch.reshape((1, 60, 1))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# ...
# 1/1 [==============================] - 0s 56ms/step

# %%
test_predictions
# Out:
# [array([0.71904945], dtype=float32),
#  array([0.7210352], dtype=float32),
#  array([0.7238951], dtype=float32),
#  array([0.72773814], dtype=float32),
#  array([0.7325623], dtype=float32),
#  array([0.73826873], dtype=float32),
#  array([0.7446984], dtype=float32),
#  array([0.75166583], dtype=float32),
#  array([0.7589917], dtype=float32),
#  array([0.76653314], dtype=float32),
#  array([0.7741882], dtype=float32),
#  array([0.78189737], dtype=float32),
#  array([0.7896421], dtype=float32),
#  array([0.797434], dtype=float32),
#  array([0.8052917], dtype=float32),
#  array([0.81324846], dtype=float32),
#  array([0.8213336], dtype=float32),
#  array([0.82957095], dtype=float32),
#  array([0.83797556], dtype=float32),
#  array([0.8465551], dtype=float32),
#  array([0.8553087], dtype=float32),
#  array([0.864228], dtype=float32),
#  array([0.8733045], dtype=float32),
#  array([0.8825292], dtype=float32),
#  array([0.8918919], dtype=float32),
#  array([0.9013858], dtype=float32),
# ...

# %%
p= sc.inverse_transform(test_predictions)

# %%
p
# Out:
# array([[182.54404302],
#        [182.89408729],
#        [183.3982288 ],
#        [184.07568504],
#        [184.92608826],
#        [185.93201769],
#        [187.06544035],
#        [188.29365813],
#        [189.58506565],
#        [190.91446688],
#        [192.26390516],
#        [193.62287338],
#        [194.98811434],
#        [196.36166643],
#        [197.74682887],
#        [199.14944362],
#        [200.57469067],
#        [202.02677288],
#        [203.50833803],
#        [205.02074154],
#        [206.5638258 ],
#        [208.13611982],
#        [209.73612108],
#        [211.36225352],
#        [213.01270991],
#        [214.68629244],
#        [216.38140403],
#        [218.09716209],
#        [219.83195903],
#        [221.58535355],
#        [223.35621088],
#        [225.14224047],
#        [226.94268582],
#        [228.75571867],
#        [230.57859669],
#        [232.40907135],
#        [234.24445282],
#        [236.08178862],
#        [237.91748531],
#        [239.74763424],
# ...

# %%
test["p"]=p
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\1836428314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["p"]=p

# %%
test
# Out:
#                  Close           p
# Date
# 2019-03-14  183.729996  182.544043
# 2019-03-15  186.119995  182.894087
# 2019-03-18  188.020004  183.398229
# 2019-03-19  186.529999  184.075685
# 2019-03-20  188.160004  184.926088
# ...                ...         ...
# 2019-12-23  284.000000  251.450702
# 2019-12-24  284.269989  251.683729
# 2019-12-26  289.910004  251.881872
# 2019-12-27  289.799988  252.045131
# 2019-12-30  291.519989  252.173528
#
# [202 rows x 2 columns]

# %%
# Visualising the results
plt.figure(figsize=(15,8))
plt.plot(test["Close"], color='Red', label='Real Apple Stock Price')
plt.plot(test["p"], color='Blue', label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction',fontsize=20)
plt.xlabel('Time', fontsize=15)
plt.ylabel('Apple Stock Price',fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# # Giving the 202 days input and predicting the next 202 days stock price

# %%
test_predictions = []

first_eval_batch = trainig_set_scaled[-202:]
current_batch = first_eval_batch.reshape((1, 202, 1))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# ...
# 1/1 [==============================] - 0s 121ms/step

# %%
model.predict(current_batch)
# Out:
# 1/1 [==============================] - 0s 105ms/step
# array([[1.1176881]], dtype=float32)

# %%
current_batch.shape
# Out:
# (1, 202, 1)

# %%
p2= sc.inverse_transform(test_predictions)

# %%
p2
# Out:
# array([[182.5590892 ],
#        [182.90928057],
#        [183.41384236],
#        [184.09206562],
#        [184.94365615],
#        [185.95119316],
#        [187.08646507],
#        [188.31689985],
#        [189.61139646],
#        [190.94417047],
#        [192.29721268],
#        [193.66013158],
#        [195.02940728],
#        [196.40646874],
#        [197.79560286],
#        [199.20243096],
#        [200.63217506],
#        [202.08916408],
#        [203.57587771],
#        [205.09353478],
#        [206.64191462],
#        [208.22004008],
#        [209.82619851],
#        [211.45869825],
#        [213.11576361],
#        [214.79600765],
#        [216.49804343],
#        [218.22083074],
#        [219.96326635],
#        [221.7243941 ],
#        [223.50308973],
#        [225.29805036],
#        [227.10772095],
#        [228.93010513],
#        [230.76317504],
#        [232.60431441],
#        [234.45068632],
#        [236.29897052],
#        [238.14590982],
#        [239.98753251],
# ...

# %%
test["p2"]=p2
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\1459125308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["p2"]=p2

# %%
# Visualising the results
plt.figure(figsize=(15,8))
plt.plot(test["Close"], color='Red', label='Real Apple Stock Price')
plt.plot(test["p2"], color='Blue', label='Predicted Apple Stock Price')
plt.title('Apple Stock Price Prediction',fontsize=20)
plt.xlabel('Time', fontsize=15)
plt.ylabel('Apple Stock Price',fontsize=15)
plt.legend()
plt.show()

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
                         # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse,  
            'corr':corr, 'minmax':minmax})

forecast_accuracy(test["p2"], test["Close"])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\4233513313.py:8: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   mins = np.amin(np.hstack([forecast[:,None],
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\4233513313.py:9: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\4233513313.py:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   maxs = np.amax(np.hstack([forecast[:,None],
# ...

# %% [markdown]
# Deployment

# %%
from pickle import dump
dump(stock,open('data_close.sav','wb'))
